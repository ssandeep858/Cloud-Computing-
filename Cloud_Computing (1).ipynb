# %%
import pandas as pd

# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt

# %%
data=pd.read_csv('deaths_latest.csv')

# %%
data
# Out:
#     Cases  Recovered  Deaths
# 0  618923      49998   27112

# %%
fig=plt.figure()

# %%
ax=fig.add_axes([0,0,1,1])

# %%
type=['Total_Cases','Recovered_Cases','Deaths_Cases']

# %%
people=[618923,49998,27112]

# %%
plt.bar(type,people,label='Infected Peoples',color='b')

plt.title('Cases of COVID_19 in USA ')
plt.ylabel('Number of Cases')
plt.legend()

# %%
age=pd.read_csv('age.csv')

# %%
age
# Out:
#     AGE   Cases
# 0     1    2878
# 1     4     574
# 2    14     842
# 3    24    4852
# 4    34   10183
# 5    44   14618
# 6    54   28221
# 7    64   68356
# 8    74  106462
# 9    84  134217
# 10  100  170731

# %%
ax=fig.add_axes([0,0,1,1])
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "

# %%
Cases=[2878,574,842,4852,10183,14618,28221,68356,106462,134217,170731]

# %%
AGE=[1,4,14,24,34,44,54,64,74,84,100]

# %%
Cases_disp=['2878','574','842','4852','10183','14618','28221','68356','106462','134217','170731']

# %%
import numpy as np

# %%
plt.yticks(np.arange(min(Cases), max(Cases), 5000))
plt.xticks(np.arange(min(AGE), max(AGE), 5.0))
plt.xlabel('AGE OF PATIENTS')
plt.ylabel('NO OF CASES')
plt.bar(AGE,Cases)
plt.legend(['Cases'])
plt.title('"CASES WITH REFERENCE TO AGE OF PEOPLE"')
# Out:
# Text(0.5, 1.0, '"CASES WITH REFERENCE TO AGE OF PEOPLE"')

# %%
date=pd.read_csv('us.csv')

# %%
date
# Out:
#           date   cases  deaths
# 0   2020-01-21       1       0
# 1   2020-01-22       1       0
# 2   2020-01-23       1       0
# 3   2020-01-24       2       0
# 4   2020-01-25       3       0
# 5   2020-01-26       5       0
# 6   2020-01-27       5       0
# 7   2020-01-28       5       0
# 8   2020-01-29       5       0
# 9   2020-01-30       6       0
# 10  2020-01-31       7       0
# 11  2020-02-01       8       0
# 12  2020-02-02      11       0
# 13  2020-02-03      11       0
# 14  2020-02-04      11       0
# 15  2020-02-05      12       0
# 16  2020-02-06      12       0
# 17  2020-02-07      12       0
# 18  2020-02-08      12       0
# 19  2020-02-09      12       0
# 20  2020-02-10      13       0
# 21  2020-02-11      13       0
# 22  2020-02-12      14       0
# 23  2020-02-13      15       0
# 24  2020-02-14      15       0
# 25  2020-02-15      15       0
# 26  2020-02-16      15       0
# 27  2020-02-17      25       0
# 28  2020-02-18      25       0
# ...

# %%
df=pd.DataFrame(date)

# %%
date_list=df["date"].tolist()

# %%
case_list=df["cases"].tolist()

# %%
death_list=df["deaths"].tolist()

# %%
plt.figure(figsize=(10,5))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = [20, 15]

# %%
plt.yticks(np.arange(min(case_list), max(case_list), 10000))
plt.xticks(np.arange(min(death_list), max(death_list), 10))
plt.xlabel('DATE',fontsize=20)
plt.ylabel('NO OF CASES',fontsize=20)

plt.title('"CASES REPORT WITH INCREASE IN DATE "',fontsize=20)
plt.plot(date_list,case_list)
plt.plot(date_list,death_list)
plt.legend(['Cases','Deaths'] , prop={"size":20})

# %%
sex=pd.read_csv('sex.csv')

# %%
sex
# Out:
#       Sex  Deaths
# 0    Male  278621
# 1  Female  263295

# %%
df=pd.DataFrame(sex)
Deaths_list=df["Deaths"].tolist()
Sex=["Male","Female"]

# %%
plt.xlabel('278621                                                              263295',fontsize=20)
plt.ylabel('NO OF CASES',fontsize=20)
plt.bar(Sex,Deaths_list)
plt.legend(['Cases'], prop={"size":20})

 


plt.title('"CASES WITH REFERENCE TO SEX OF PEOPLE"',fontsize=20)
# Out:
# Text(0.5, 1.0, '"CASES WITH REFERENCE TO SEX OF PEOPLE"')

# %%
reason=pd.read_csv('Reason.csv')

# %%
df=pd.DataFrame(reason)

# %%
df
# Out:
#                 Source   Cases
# 0      Travel Related     6515
# 1        Close Contact   13341
# 2  Under Investigation  534993
# 3          Total Cases  554849

# %%
plt.figure(figsize=(7,7))

plt.xlabel('6515              13341                534993                       554849')
plt.ylabel('NO OF CASES')
plt.plot(df.Source,df.Cases)
plt.legend(['Cases'])
plt.title('"REASON OF CORONA VIRUS SPREAD "')
# Out:
# Text(0.5, 1.0, '"REASON OF CORONA VIRUS SPREAD "')

# %%
place=pd.read_csv('Place.csv')

# %%
place
# Out:
#              Total  541934
# 0        Inpatient  153817
# 1       Outpatient   32468
# 2  Dead on Arrival    1440
# 3             Home  174898
# 4         Hospital   41291
# 5    Nusrsing Home  103617
# 6            Other   34320
# 7         Unnknown      83

# %%
df=pd.DataFrame(place)

# %%
plist=df["541934"].tolist()

# %%
pllist=df["Total"].tolist()

# %%
plt.figure(figsize=(10,10))
  
plt.xlabel('153817            32468          1440        174898         41291        103617          34320        83')
plt.ylabel('PLACE OF DEATHS')
plt.bar(df.Total,plist,color='Black')
plt.legend(['People'])
plt.title('"DEATHS CAUSED BY COVID-19 , PNEUMONIA AND INFLUENZA INCLUSIVE "')
# Out:
# Text(0.5, 1.0, '"DEATHS CAUSED BY COVID-19 , PNEUMONIA AND INFLUENZA INCLUSIVE "')

# %%
state=pd.read_csv('Collected.csv')
df=pd.DataFrame(state)
slist=df["State"].tolist()
clist=df["Confirmed"].tolist()
dlist=df["Deaths"].tolist()

# %%
df
# Out:
#                    State  Confirmed  Deaths  Recovered
# 0                Alabama       3836     109        NaN
# 1                 Alaska        272       8       66.0
# 2                Arizona       3806     131        NaN
# 3               Arkansas       1498      32      444.0
# 4             California      23338     758      810.0
# 5               Colorado       7303     290        NaN
# 6            Connecticut      12035     554        NaN
# 7               Delaware       1761      41      277.0
# 8   District of Columbia       2062      68      518.0
# 9                Florida      21367     524        NaN
# 10               Georgia      14223     501        NaN
# 11                  Guam        133       5       58.0
# 12                Hawaii        504       9      310.0
# 13                 Idaho       1453      33        NaN
# 14              Illinois      23247     868        NaN
# 15               Indiana       8527     387        NaN
# ...

# %%
Z = [x for _,x in sorted(zip(clist,slist))]

# %%
clist.sort()

# %%
ax=fig.add_axes([0,0,1,1])
plt.figure(figsize=(25,20))
plt.xlabel('STATES',fontsize=20)
plt.ylabel('CASES',fontsize=20)
plt.bar(Z,clist)
plt.xticks(plt.xticks()[0], Z, rotation=90)
plt.yticks(np.arange(min(clist), max(clist), 5000))
plt.legend(['AFFECTED'] , prop={"size":20})

plt.title('"AFFECTED PEOPLE IN EACH STATES"',fontsize=20)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
# Text(0.5, 1.0, '"AFFECTED PEOPLE IN EACH STATES"')

# %%
df
# Out:
#                    State  Confirmed  Deaths  Recovered
# 0                Alabama       3836     109        NaN
# 1                 Alaska        272       8       66.0
# 2                Arizona       3806     131        NaN
# 3               Arkansas       1498      32      444.0
# 4             California      23338     758      810.0
# 5               Colorado       7303     290        NaN
# 6            Connecticut      12035     554        NaN
# 7               Delaware       1761      41      277.0
# 8   District of Columbia       2062      68      518.0
# 9                Florida      21367     524        NaN
# 10               Georgia      14223     501        NaN
# 11                  Guam        133       5       58.0
# 12                Hawaii        504       9      310.0
# 13                 Idaho       1453      33        NaN
# 14              Illinois      23247     868        NaN
# 15               Indiana       8527     387        NaN
# ...

# %%
rlist=df["Recovered"].tolist()
dlist=df["Deaths"].tolist()

# %%
Z = [x for _,x in sorted(zip(dlist,slist))]
Y = [y for _,y in sorted(zip(dlist,rlist))]

# %%
dlist.sort()

# %%
plt.figure(figsize=(20,10))
plt.xlabel('STATES',fontsize=20)
plt.ylabel('CASES',fontsize=20)
plt.plot(Z,dlist)
plt.plot(Z,rlist,'bo',color='black')

plt.grid()
plt.xticks(plt.xticks()[0], Z, rotation=90)

plt.legend(['DEATH PATIENTS','RECOVERED PATIENTS'] , prop={"size":20})

plt.title('"" STATES WISE DATA "',fontsize=20)
# Out:
# Text(0.5, 1.0, '"" STATES WISE DATA "')

# %%
death=pd.read_csv('deaths.csv')

# %%
death
# Out:
#                     State Confirmed  Deaths
# 0                Alabama:     4,241     123
# 1                 Alaska:       293       9
# 2                Arizona:     3,962     142
# 3               Arkansas:     1,599      34
# 4             California:    27,097     889
# 5               Colorado:     8,280     357
# 6            Connecticut:    14,755     868
# 7               Delaware:     2,014      46
# 8   District of Columbia:     2,197      72
# 9                Florida:    22,519     614
# 10               Georgia:    15,260     576
# 11                Hawaii:       530       9
# 12                 Idaho:     1,587      41
# 13              Illinois:    24,593     948
# 14               Indiana:     8,955     436
# 15                  Iowa:     1,995      53
# 16                Kansas:     1,494      76
# 17              Kentucky:     2,291     122
# 18             Louisiana:    21,951   1,103
# 19                 Maine:       770      24
# ...

# %%
df=pd.DataFrame(death)
ax=fig.add_axes([0,0,1,1])
plt.figure(figsize=(25,20))
plt.xlabel('STATES',fontsize=20)
plt.ylabel('CASES',fontsize=20)
plt.bar(slist,dlist)


plt.grid()
plt.xticks(plt.xticks()[0], Z, rotation=90)
ax.set_ylim([min(clist),None])
#plt.yticks(np.arange(min(clist), 50000, 500))
plt.legend(['DEAD'] , prop={"size":20})

plt.title('"DEAD PEOPLE IN EACH STATES"',fontsize=20)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
# Text(0.5, 1.0, '"DEAD PEOPLE IN EACH STATES"')

# %%
Z = [x for _,x in sorted(zip(rlist,slist))]

# %%
rlist.sort()

# %%
plt.figure(figsize=(20,10))
plt.xlabel('STATES',fontsize=20)
plt.ylabel('CASES',fontsize=20)
plt.bar(Z,rlist )


plt.grid()
plt.xticks(plt.xticks()[0], Z, rotation=90)

plt.legend(['RECOVERED PATIENTS'] , prop={"size":20})

plt.title('"" STATES WISE DATA "',fontsize=20)
# Out:
# Text(0.5, 1.0, '"" STATES WISE DATA "')
